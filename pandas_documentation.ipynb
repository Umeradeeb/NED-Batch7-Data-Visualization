# %%
import pandas as pd
import numpy as np

# %%
#list
pd.Series ([1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#tuple
pd.Series((1,2,3,4))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#dictionary
pd.Series(({'a':1,'b':2,'c':3,'d':4}))
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
#No data frame from set
pd.Series({1,2,3,4})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c551b8f80ecc> in <cell line: 2>()
#       1 #No data frame from set
# ----> 2 pd.Series({1,2,3,4})
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     510                 data = data.copy()
#     511         else:
# --> 512             data = sanitize_array(data, index, dtype, copy)
#     513
#     514             manager = get_option("mode.data_manager")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     639
#     640     else:
# --> 641         _sanitize_non_ordered(data)
#     642         # materialize e.g. generators, convert e.g. tuples, abc.ValueView
#     643         data = list(data)
#
# ...

# %% [markdown]
# # DataFrame

# %%
# list within a list
pd.DataFrame([[1,2,3,4],[5,6,7,8]])
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
# numpy 2d array
pd.DataFrame(np.array([[1,2,3,4],[5,6,7,8]]))
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
# dictionary
pd.DataFrame(({'a':[1,2,3],'b':[5,6,7]}))
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7

# %%
# read csv data from github
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# https://www.kaggle.com/discussions/general/74235

# %%
# install kaggle python package
! pip install -q kaggle

# %%
# create .kaggle folder
! mkdir ~/.kaggle

#copy kaggle.jason file to kaggle.folder
! cp kaggle.json ~/.kaggle/

# %%
# provide rights
! chmod 600 ~/.kaggle/kaggle.json

# %%
# check datasets list from kaggle
! kaggle datasets list
# Out:
# ref                                                              title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# lainguyn123/student-performance-factors                          Student Performance Factors                          94KB  2024-09-02 10:53:57          12910        272  1.0
# owm4096/laptop-prices                                            Laptop Prices                                        25KB  2024-09-09 12:43:01           3318         60  1.0
# taweilo/mba-admission-dataset                                    MBA Admission dataset, Class 2025                    55KB  2024-09-18 07:57:38           1381         28  1.0
# ...

# %%
# download specific competition dataset
! kaggle datasets download -d akshaydattatraykhare/diabetes-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/akshaydattatraykhare/diabetes-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/8.91k [00:00<?, ?B/s]
# 100% 8.91k/8.91k [00:00<00:00, 17.2MB/s]

# %%
# unzip file
# !unzip diabetes-dataset.zip
# Out:
# Archive:  diabetes-dataset.zip
#   inflating: diabetes.csv

# %%
df1 = pd.read_csv('diabetes.csv')
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# prompt: Using dataframe df1: I want age distribution of diabetes patients

# Filter the dataframe to include only patients with diabetes (Outcome = 1)
diabetes_patients = df1[df1['Outcome'] == 1]

# Plot the age distribution of diabetes patients using a histogram
diabetes_patients['Age'].plot(kind='hist', title='Age Distribution of Diabetes Patients')
# Out:
# <Axes: title={'center': 'Age Distribution of Diabetes Patients'}, ylabel='Frequency'>

# %%
# !kaggle datasets download -d heptapod/titanic
# Out:
# Dataset URL: https://www.kaggle.com/datasets/heptapod/titanic
# License(s): DbCL-1.0
# ...
#   0% 0.00/10.8k [00:00<?, ?B/s]
# 100% 10.8k/10.8k [00:00<00:00, 16.6MB/s]

# %%
# !unzip titanic.zip
# Out:
# Archive:  titanic.zip
#   inflating: train_and_test2.csv

# %%
df2 = pd.read_csv('train_and_test2.csv')
df2
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
# prompt: create hello world streamlit code and run it

# !pip install -q streamlit
# %%writefile app.py
import streamlit as st

st.write('Hello, world!')
# !streamlit run app.py &>/dev/null&
# !npx localtunnel --port 8501
